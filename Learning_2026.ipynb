# %% [markdown]
# <a href="https://colab.research.google.com/github/Dwarakasekar/C2TC_CoreJava/blob/master/Learning_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Learning started to become the Software Developer")
# Out:
# Learning started to become the Software Developer

# %% [markdown]
# Task - 1

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
print(a+b)
# Out:
# Enter the first number12
# Enter the second number24
# 36

# %% [markdown]
# Task - 2
# **bold text**
#
# Variables and Data types

# %%
Values = {'Name': 'Dwaraka','Age':'22','Role':'Backend Developer'}
print("Personal Information",Values)
# Out:
# Personal Information {'Name': 'Dwaraka', 'Age': '22', 'Role': 'Backend Developer'}

# %% [markdown]
# Please copy the text from the desired text cell (e.g., the cell with many built-in functions) and paste it into the `multiline_text` variable in the code cell below. Then run the cell.

# %%
multiline_text = """
abs()

delattr()

hash()

memoryview()

set()

all()

dict()

help()

min()

setattr()

any()

dir()

hex()

next()

slice()

ascii()

divmod()

id()

object()

sorted()

bin()

enumerate()

input()

oct()

staticmethod()

bool()

eval()

int()

open()

str()

breakpoint()

exec()

isinstance()

ord()

sum()

bytearray()

filter()

issubclass()

pow()

super()

bytes()

float()

iter()

print()

tuple()

callable()

format()

len()

property()

type()

chr()

frozenset()

list()

range()

vars()

classmethod()

getattr()

locals()

repr()

zip()

compile()

globals()

map()

reversed()

__import__()

complex()

hasattr()

max()

round()
"""

# Replace newlines with spaces and split by any whitespace
words = multiline_text.split()

print("\nText as a single sentence:\n", words)
# Out:
# Text as a single sentence:
#  ['abs()', 'delattr()', 'hash()', 'memoryview()', 'set()', 'all()', 'dict()', 'help()', 'min()', 'setattr()', 'any()', 'dir()', 'hex()', 'next()', 'slice()', 'ascii()', 'divmod()', 'id()', 'object()', 'sorted()', 'bin()', 'enumerate()', 'input()', 'oct()', 'staticmethod()', 'bool()', 'eval()', 'int()', 'open()', 'str()', 'breakpoint()', 'exec()', 'isinstance()', 'ord()', 'sum()', 'bytearray()', 'filter()', 'issubclass()', 'pow()', 'super()', 'bytes()', 'float()', 'iter()', 'print()', 'tuple()', 'callable()', 'format()', 'len()', 'property()', 'type()', 'chr()', 'frozenset()', 'list()', 'range()', 'vars()', 'classmethod()', 'getattr()', 'locals()', 'repr()', 'zip()', 'compile()', 'globals()', 'map()', 'reversed()', '__import__()', 'complex()', 'hasattr()', 'max()', 'round()']

# %%
numbers = [1,2,4,5,6]
num = max(numbers)
print(num)
enngal = 732.10
first_name = "Dwaraka"
last_name = "Sekar"
full_name = "Dwaraka Sekar"
country = "India"
city = "Hyderabad"
age = 22
year = 2023
is_married = False
is_true = True
is_light_on = True
val1, val2 , val3 = 10,20,30


values = "Hi backend deve4loper nice to wiorj with oyyouy"
print(len(values))
print(type(words))
print(round(enngal))
# Out:
# 6
# 47
# <class 'list'>
# 732

# %% [markdown]
# **want to check the type of the variable by assigning single variable**
#
#  **Question:**  Check the data type of all your variables using type() built-in function

# %%
types = [first_name, last_name, full_name, country, city, age, year, is_married, is_true, is_light_on, val1, val2, val3]

identity_type = []


for i in range(len(types)):
  identity_type.append(type(types[i]))

print(identity_type)
# Out:
# [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'int'>, <class 'int'>, <class 'bool'>, <class 'bool'>, <class 'bool'>, <class 'int'>, <class 'int'>, <class 'int'>]

# %% [markdown]
# **Line comphrension for previous code**

# %%
[(type(i)) for i in types]
# Out:
# [str, str, str, str, str, int, int, bool, bool, bool, int, int, int]

# %% [markdown]
# **Task - 2 - chatgpt task**
#
# ✅Program 1: User Details
#
# Ask name
#
# Ask age
#
# Print a message using both
# # New Section
# ✅ Program 2: Eligibility Checker
#
# Take a number from user
#
# Check if it is positive, negative, or zero
#
# ✅ Program 3: Loop Practice
#
# Print numbers from 1 to 10
#
# Use any one loop

# %%
Name = input("Enter your name")
Age = int(input("Enter your age"))
print("Hi! ",Name,"You're ",Age)
if(Age>0):
  print("positive number")
elif Age<0:
  print("negative number")
else:
  print("zero")
for i in range(1,Age):
  print(i)
# Out:
# Enter your name5
# Enter your age4
# Hi!  5 You're  4
# positive number
# 1
# 2
# 3

# %% [markdown]
# **Exercises: Level 2**
# 1.
# Declare 5 as num_one and 4 as num_two
# Add num_one and num_two and assign the value to a variable total
#
# 2.Subtract num_two from num_one and assign the value to a variable diff
#
# 3.Multiply num_two and num_one and assign the value to a variable product
#
# 4.Divide num_one by num_two and assign the value to a variable division
#
# 5.Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
#
# 6.Calculate num_one to the power of num_two and assign the value to a variable exp
#
# 7.Find floor division of num_one by num_two and assign the value to a variable floor_division
#
# 8.The radius of a circle is 30 meters.
#
# 9.Calculate the area of a circle and assign the value to a variable name of area_of_circle
#
# 10.Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
#
# 11.Take radius as user input and calculate the area.
#
# 12. Run help('keywords') in Python shell or in your file to check for the Python reserved words or keywords

# %%
import math
num_one=5
num_two=4
radius = int(input("enter the radius:"))
total = num_one + num_two
variable_diff = num_one - num_two
variable_product = num_one * num_two
variable_divison = num_one / num_two
variable_remainder= num_one % num_two
variable_exp= num_one ** num_two
variable_floor_division= num_one // num_two
circle_area = math.pi*radius**2
circum_of_circle = 2*math.pi*radius
print(circle_area)
# Out:
# enter the radius:3
# 28.274333882308138

# %% [markdown]
# # Operators

# %%
age=22
height=172
complex=1+2j
base=int(input("enter the base"))
height = int(input("enter the height"))
area_of_triangle = 0.5*base*height
a=int(input("enter the first side"))
b=int(input("enter the second side"))
c=int(input("enter the third side"))
perimenter = a+b+c
# Out:
# enter the base6
# enter the height7
# enter the first side8
# enter the second side9
# enter the third side2
